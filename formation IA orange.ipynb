# %%
import pandas

# %%
dataset = pandas.read_csv('water_potability.csv')

# %%
dataset.shape
# Out:
# (3276, 10)

# %%
dataset.columns
# Out:
# Index(['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
#        'Organic_carbon', 'Trihalomethanes', 'Turbidity', 'Potability'],
#       dtype='object')

# %%
dataset.drop(['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity'], axis=1, inplace=True)

# %%
dataset.columns
# Out:
# Index(['Organic_carbon', 'Trihalomethanes', 'Turbidity', 'Potability'], dtype='object')

# %%
dataset.head()
# Out:
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0
